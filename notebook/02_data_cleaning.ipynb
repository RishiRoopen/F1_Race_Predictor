# %% [markdown]
# # 02 - Data Cleaning
#
# This notebook loads raw qualifying & race results for the 2023 Bahrain GP,
# checks data quality, and outputs **cleaned datasets** into `data/processed/`.
#
# - Standardizes column names
# - Converts times to numeric values
# - Handles missing values
# - Prepares data for exploratory analysis

# %% [markdown]
# ### 1. Import & Setup

# %%
import pandas as pd
import os

# Paths
raw_path = r"C:\UNI\Code\F1_Race_Predictor\data\raw"
processed_path = r"C:\UNI\Code\F1_Race_Predictor\data\processed"

os.makedirs(processed_path, exist_ok=True)

# %% [markdown]
# ### 2. Load Raw Data

# %%
season = 2023
gp = "Great Britain"

q_results = pd.read_csv(fr"{raw_path}\{season}_{gp}_qualifying.csv")
r_results = pd.read_csv(fr"{raw_path}\{season}_{gp}_race.csv")

print("Qualifying Results:")
display(q_results.head())

print("Race Results:")
display(r_results.head())
# Out:
# Qualifying Results:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 0             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 1             4      L NORRIS          NOR          norris          McLaren
# 2            81     O PIASTRI          PIA         piastri          McLaren
# 3            16     C LECLERC          LEC         leclerc          Ferrari
# 4            55       C SAINZ          SAI           sainz          Ferrari
#
#   TeamColor    TeamId FirstName    LastName         FullName  ... Position  \
# 0    3671C6  red_bull       Max  Verstappen   Max Verstappen  ...      1.0
# 1    F58020   mclaren     Lando      Norris     Lando Norris  ...      2.0
# 2    F58020   mclaren     Oscar     Piastri    Oscar Piastri  ...      3.0
# 3    F91536   ferrari   Charles     Leclerc  Charles Leclerc  ...      4.0
# 4    F91536   ferrari    Carlos       Sainz     Carlos Sainz  ...      5.0
#
#   ClassifiedPosition  GridPosition                      Q1  \
# 0                NaN           NaN  0 days 00:01:29.428000
# 1                NaN           NaN  0 days 00:01:28.917000
# 2                NaN           NaN  0 days 00:01:29.874000
# 3                NaN           NaN  0 days 00:01:29.143000
# 4                NaN           NaN  0 days 00:01:29.865000
#
#                        Q2                      Q3 Time Status  Points  Laps
# 0  0 days 00:01:27.702000  0 days 00:01:26.720000  NaN    NaN     NaN   NaN
# 1  0 days 00:01:28.042000  0 days 00:01:26.961000  NaN    NaN     NaN   NaN
# 2  0 days 00:01:27.845000  0 days 00:01:27.092000  NaN    NaN     NaN   NaN
# 3  0 days 00:01:28.361000  0 days 00:01:27.136000  NaN    NaN     NaN   NaN
# 4  0 days 00:01:28.265000  0 days 00:01:27.148000  NaN    NaN     NaN   NaN
#
# [5 rows x 22 columns]
# Race Results:
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 0             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 1             4      L NORRIS          NOR          norris          McLaren
# 2            44    L HAMILTON          HAM        hamilton         Mercedes
# 3            81     O PIASTRI          PIA         piastri          McLaren
# 4            63     G RUSSELL          RUS         russell         Mercedes
#
#   TeamColor    TeamId FirstName    LastName        FullName  ... Position  \
# 0    3671C6  red_bull       Max  Verstappen  Max Verstappen  ...      1.0
# 1    F58020   mclaren     Lando      Norris    Lando Norris  ...      2.0
# 2    6CD3BF  mercedes     Lewis    Hamilton  Lewis Hamilton  ...      3.0
# 3    F58020   mclaren     Oscar     Piastri   Oscar Piastri  ...      4.0
# 4    6CD3BF  mercedes    George     Russell  George Russell  ...      5.0
#
#   ClassifiedPosition  GridPosition  Q1  Q2  Q3                    Time  \
# 0                  1           1.0 NaN NaN NaN  0 days 01:25:16.938000
# 1                  2           2.0 NaN NaN NaN  0 days 00:00:03.798000
# 2                  3           7.0 NaN NaN NaN  0 days 00:00:06.783000
# 3                  4           3.0 NaN NaN NaN  0 days 00:00:07.776000
# 4                  5           6.0 NaN NaN NaN  0 days 00:00:11.206000
#
#      Status Points  Laps
# 0  Finished   26.0  52.0
# 1  Finished   18.0  52.0
# 2  Finished   15.0  52.0
# 3  Finished   12.0  52.0
# 4  Finished   10.0  52.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 3. Check Data Quality

# %%
print("Qualifying Info:")
q_results.info()
print("\nMissing values in Qualifying:")
print(q_results.isna().sum())

print("\nRace Info:")
r_results.info()
print("\nMissing values in Race:")
print(r_results.isna().sum())
# Out:
# Qualifying Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     int64
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  0 non-null      float64
#  14  GridPosition        0 non-null      float64
#  15  Q1                  20 non-null     object
#  16  Q2                  14 non-null     object
#  17  Q3                  10 non-null     object
#  18  Time                0 non-null      float64
#  19  Status              0 non-null      float64
#  20  Points              0 non-null      float64
#  21  Laps                0 non-null      float64
# dtypes: float64(7), int64(1), object(14)
# memory usage: 3.6+ KB
#
# Missing values in Qualifying:
# DriverNumber           0
# BroadcastName          0
# Abbreviation           0
# DriverId               0
# TeamName               0
# TeamColor              0
# TeamId                 0
# FirstName              0
# LastName               0
# FullName               0
# HeadshotUrl            0
# CountryCode            0
# Position               0
# ClassifiedPosition    20
# GridPosition          20
# Q1                     0
# Q2                     6
# Q3                    10
# Time                  20
# Status                20
# Points                20
# Laps                  20
# dtype: int64
#
# Race Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        20 non-null     int64
#  1   BroadcastName       20 non-null     object
#  2   Abbreviation        20 non-null     object
#  3   DriverId            20 non-null     object
#  4   TeamName            20 non-null     object
#  5   TeamColor           20 non-null     object
#  6   TeamId              20 non-null     object
#  7   FirstName           20 non-null     object
#  8   LastName            20 non-null     object
#  9   FullName            20 non-null     object
#  10  HeadshotUrl         20 non-null     object
#  11  CountryCode         20 non-null     object
#  12  Position            20 non-null     float64
#  13  ClassifiedPosition  20 non-null     object
#  14  GridPosition        20 non-null     float64
#  15  Q1                  0 non-null      float64
#  16  Q2                  0 non-null      float64
#  17  Q3                  0 non-null      float64
#  18  Time                17 non-null     object
#  19  Status              20 non-null     object
#  20  Points              20 non-null     float64
#  21  Laps                20 non-null     float64
# dtypes: float64(7), int64(1), object(14)
# memory usage: 3.6+ KB
#
# Missing values in Race:
# DriverNumber           0
# BroadcastName          0
# Abbreviation           0
# DriverId               0
# TeamName               0
# TeamColor              0
# TeamId                 0
# FirstName              0
# LastName               0
# FullName               0
# HeadshotUrl            0
# CountryCode            0
# Position               0
# ClassifiedPosition     0
# GridPosition           0
# Q1                    20
# Q2                    20
# Q3                    20
# Time                   3
# Status                 0
# Points                 0
# Laps                   0
# dtype: int64

# %% [markdown]
# ### 4. Cleaning - Standardize & Fix

# %%
# --- Column Name Fixes ---
q_results.rename(columns=lambda x: x.strip().title(), inplace=True)
r_results.rename(columns=lambda x: x.strip().title(), inplace=True)

# --- Ensure Position is int ---
if 'Position' in q_results.columns:
    q_results['Position'] = pd.to_numeric(q_results['Position'], errors='coerce')
if 'Position' in r_results.columns:
    r_results['Position'] = pd.to_numeric(r_results['Position'], errors='coerce')

# --- Convert Times ---
time_cols = ['Q1', 'Q2', 'Q3']
for col in time_cols:
    if col in q_results.columns:
        q_results[col] = pd.to_timedelta(q_results[col], errors='coerce')

if 'FastestLapTime' in r_results.columns:
    r_results['FastestLapTime'] = pd.to_timedelta(r_results['FastestLapTime'], errors='coerce')

# --- Add Numeric Seconds Columns ---
for col in time_cols:
    if col in q_results.columns:
        q_results[col + "_sec"] = q_results[col].dt.total_seconds()

if 'FastestLapTime' in r_results.columns:
    r_results['FastestLapTime_sec'] = r_results['FastestLapTime'].dt.total_seconds()

# %% [markdown]
# ### 5. Encode Status (Finished/DNF)

# %%
if 'Status' in r_results.columns:
    r_results['Finished'] = r_results['Status'].apply(lambda x: 0 if 'DNF' in str(x) or 'Retired' in str(x) else 1)

# %% [markdown]
# ### 6. Save Cleaned Data

# %%
q_results.to_csv(fr"{processed_path}\{season}_{gp}_qualifying_clean.csv", index=False)
r_results.to_csv(fr"{processed_path}\{season}_{gp}_race_clean.csv", index=False)

print("✅ Cleaned data saved to:", processed_path)
# Out:
# ✅ Cleaned data saved to: C:\UNI\Code\F1_Race_Predictor\data\processed
